# %% [markdown]
# # 07. Statistical Modeling & Hypothesis Testing
#
# Conducts descriptive distributional profiling, Spearman/Pearson correlation matrices, ANOVA/Kruskal-Wallis tests across dimensions, and Chi-Square test of independence.
#
# *E-Commerce Revenue Analytics | Enterprise Analytics Engineering & BI Architecture*

# %% [markdown]
# ### 1. Descriptive Distribution Statistics

# %%
import sys
from pathlib import Path
import pandas as pd

BASE_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(BASE_DIR))

from src.data_loader import load_processed_data
from src.statistical_analysis import compute_descriptive_statistics, compute_correlation_analysis, perform_inferential_tests

df = load_processed_data()
stats_df = compute_descriptive_statistics(df)
display(stats_df)

# %% [markdown]
# ### 2. Correlation Analysis (Pearson & Spearman)

# %%
corr_res = compute_correlation_analysis(df)
print("Spearman Correlation Matrix:")
display(corr_res['spearman_matrix'])

# %% [markdown]
# ### 3. Inferential Hypothesis Testing (ANOVA, Kruskal-Wallis, Chi-Square)

# %%
inferential = perform_inferential_tests(df)
import json
print(json.dumps(inferential, indent=2))
