# %% [markdown]
# # 05. Category Unit Economics & Brand Portfolio Strategy
#
# Examines product category margin contributions, discount dependency, market basket affinity, and quantitative brand portfolio classification.
#
# *E-Commerce Revenue Analytics | Enterprise Analytics Engineering & BI Architecture*

# %% [markdown]
# ### 1. Category Economics & Classification

# %%
import sys
from pathlib import Path
import pandas as pd

BASE_DIR = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.append(str(BASE_DIR))

from src.data_loader import load_processed_data
from src.category_analysis import compute_category_performance, compute_market_basket_bundling
from src.brand_analysis import compute_brand_performance
from src.visualization import plot_category_revenue_margin, plot_brand_risk_matrix

df = load_processed_data()
cat_df = compute_category_performance(df)
display(cat_df)

fig_cat = plot_category_revenue_margin(cat_df)
fig_cat.show()

# %% [markdown]
# ### 2. Market Basket Affinity & Bundling Candidates

# %%
bundling_df = compute_market_basket_bundling(df)
display(bundling_df)

# %% [markdown]
# ### 3. Brand Portfolio Classification (Anchor, Growth, Margin, Risk)

# %%
brand_df = compute_brand_performance(df)
display(brand_df.head(10))

fig_brand = plot_brand_risk_matrix(brand_df)
fig_brand.show()
